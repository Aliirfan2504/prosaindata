# %% [markdown]
# #Crawling data Twitter
# Nama : Mohammad Ali Irfan
#
# NIM  : 210411100113

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
#pemangilan list
tweets_list=[]

# %%
for i,tweet in enumerate(sntwitter.TwitterSearchScraper("Anis Baswedan since:2022-12-01 until:2023-02-19").get_items()):
    if i>1000:
        break
    tweets_list.append([tweet.content,tweet.username,])
# Out:
# <ipython-input-4-c23a3e940e41>:4: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets_list.append([tweet.content,tweet.username,])
# <ipython-input-4-c23a3e940e41>:4: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets_list.append([tweet.content,tweet.username,])

# %%
tweet = pd.DataFrame(tweets_list,columns=["text","username"])

# %%
tweet
# Out:
#                                                    text        username
# 0     @ruhutsitompul 2024 bapak ANIS BASWEDAN, mudah...   lupmotistuhuR
# 1       @alisyarief Bukan Anis Baswedan sih tidak seksi  sugito43334255
# 2     @arvindonoviar @aniesbaswedan @realAmienRais K...      benuaandin
# 3     @musniumar Maqbul...qobul do'a semua anak bang...  JuwillirSyam21
# 4     @Fahrihamzah @dedygumelar Harambagi kami parta...         afri_dk
# ...                                                 ...             ...
# 996   @Umar_Syadat770 Hanya sekedar untuk menjatuhka...       Bakhjatul
# 997   @rahmansandre Sy yqn insyaa alloh indonesia d ...        lutnisah
# 998   Sandiaga Uno adalah salah satu orang yang pern...   PAC_Argomulyo
# 999   @MediaProANIES dia mundur karena ga bisa membe...  BahrawiMoeslim
# 1000  @JarnasABWBpn Apakah AHY dan AHER/PKS akan tul...       Bakhjatul
#
# [1001 rows x 2 columns]

# %%
tweet.to_csv("Crawling tweet.csv",index=False)
